# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
bh_all = pd.read_csv('baseBHtransformada.csv')
bh_sample = pd.read_csv('amostraBH.csv')

# %%
plt.figure(figsize=(18,10))
plt.plot(bh_all['LONGITUDE'],bh_all['LATITUDE'],'.',markersize=0.5)

# %%
plt.figure(figsize=(18,10))
plt.plot(bh_sample['LONGITUDE'],bh_sample['LATITUDE'],'.',markersize=0.5)
