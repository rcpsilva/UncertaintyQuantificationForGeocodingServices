# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# Load the shapefile (replace 'path_to_shapefile.shp' with the actual path)
shapefile_path = 'PaperGeoinfo/results/SMunicipios\_2022/SP\_Municipios_2022.shp'
gdf = gpd.read_file(shapefile_path)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: PaperGeoinfo/results/SMunicipios\_2022/SP\_Municipios_2022.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# c:\Users\rcpsi\source\repos\UncertaintyQuantificationForGeocodingServices\PaperGeoinfo\results\ResultadosGeoInfo.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/rcpsi/source/repos/UncertaintyQuantificationForGeocodingServices/PaperGeoinfo/results/ResultadosGeoInfo.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> # Load the shapefile (replace 'path_to_shapefile.shp' with the actual path)
# ...

# %%
# Filter the data to select the specific city (e.g., São Paulo)
city_name = "São Paulo"  # Replace with the actual city name you want to plot
city_gdf = gdf[gdf['NM_MUN'] == city_name]

# %%
import pandas as pd

# %%
sp = pd.read_csv('/content/DadosGeoeGold.csv')
#sp = pd.read_csv('/content/geoGold_erro.csv')
sp= sp[['lonGold','latGold']].drop_duplicates()
x = sp['lonGold']
y = sp['latGold']

# %%
city_gdf.boundary.plot()
plt.plot(x,y,'k.')
plt.title('São Paulo City Map')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
# Load São Paulo city data (replace 'path_to_shapefile' with the actual path)
mg = gpd.read_file('/content/MG_Municipios_2022.shx')

# Plot the map
mg.plot()
plt.title('Minas Gerais Map')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
shapefile_path = '/content/MG_Municipios_2022.shp'
gdf = gpd.read_file(shapefile_path)

# %%
city_name = "Belo Horizonte"  # Replace with the actual city name you want to plot
city_gdf = gdf[gdf['NM_MUN'] == city_name]

# %%
bh = pd.read_csv('/content/DadosGeoeGoldBH_temp.csv',encoding='ascii')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-18-c737d11e7711> in <cell line: 1>()
# ----> 1 bh = pd.read_csv('/content/DadosGeoeGoldBH_temp.csv',encoding='ascii')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
bh.columns

# %%
bh= bh[['lonGold','latGold']].drop_duplicates()
x = bh['lonGold']
y = bh['latGold']
